# %% [markdown]
# # !! make sure you SAVE AS ... this notebook to get your own copy !!

# %%
from code.utility import Utility

# %% [markdown]
# # Define the sample and OB runs

# %%
o_exp = Utility()
o_exp.enter_input_run_numbers()

# %% [markdown]
# # Loading the data

# %%
o_exp.load_and_display_data()
# Out:
# 100%|██████████| 2628/2628 [00:29<00:00, 88.79it/s]

# %% [markdown]
# # display profile of particular region

# %%
o_exp.sample_profile_of_region_of_interest()
# Out:
# interactive(children=(IntSlider(value=278, continuous_update=False, description='x', max=512), IntSlider(value…

# %% [markdown]
# # Export this profile to a CSV file

# %%
o_exp.export_profile_to_csv()
# Out:
# Button(description='Export profile to CSV', style=ButtonStyle())

# %% [markdown]
# # Normalization

# %%
o_exp.normalize_by_sample_roi()
# Out:
# interactive(children=(IntSlider(value=278, description='x', max=512), IntSlider(value=242, description='y', ma…

# %%
o_exp.perform_normalization()
# Out:
# interactive(children=(IntSlider(value=278, continuous_update=False, description='x', max=512), IntSlider(value…
