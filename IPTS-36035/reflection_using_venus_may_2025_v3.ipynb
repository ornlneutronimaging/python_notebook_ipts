# %% [markdown]
# # !! make sure you SAVE AS ... this notebook to get your own copy !!

# %%
from code.utility import Utility

# %% [markdown]
# =============== USER INPUT ==========================================

# %%
o_exp = Utility()
o_exp.enter_sample_run_number()
# Out:
# HBox(children=(Label(value='Sample run number:'), IntText(value=8747, layout=Layout(width='100px'))), layout=L…

# %% [markdown]
# ===================================================================

# %% [markdown]
# # load the data

# %%
o_exp.load_data()
# Out:
# Spectra file: /SNS/VENUS/IPTS-36035/shared/autoreduce/mcp/images/Run_8749/Run_8749_20250515_IridiumStandardTh1deg1p5C4A_Pbfilter_0001_3099083_Spectra.txt

# %% [markdown]
# # Display white beam signal

# %%
o_exp.display_integrated_signal()

# %% [markdown]
# # normalization

# %%
o_exp.select_open_beam_region()
# Out:
# interactive(children=(IntSlider(value=278, description='x', max=512), IntSlider(value=242, description='y', ma…

# %% [markdown]
# #### Perform normalization
#
# perform the normalization using the mean counts of the region selected above as "open beam region"

# %%
o_exp.perform_normalization()
# Out:
# interactive(children=(IntSlider(value=278, continuous_update=False, description='x', max=512), IntSlider(value…

# %% [markdown]
# # Rebining the data

# %%
o_exp.interactive_rebin()
# Out:
# interactive(children=(IntSlider(value=2, description='Bin factor', min=1), Output()), _dom_classes=('widget-in…
